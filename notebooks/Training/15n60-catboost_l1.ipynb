# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
from typing import List, Callable, Tuple, Any
from wandb.wandb_run import Run
from datetime import datetime, timedelta
from copy import deepcopy

from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier, Pool, metrics, cv

import attr
import pandas as pd
import pandas_ta as pta
import gc
import os
import wandb
import nest_asyncio
import logging
import sys
import numpy as np

while "freqtrade" not in os.listdir():
    os.chdir("..")
    if "freqtrade" in os.listdir():
        nest_asyncio.apply()
        logger = logging.getLogger("freqtrade.ml")
        handler = logging.StreamHandler(stream=sys.stdout)
        handler.setFormatter(logging.Formatter("%(name)s - %(message)s"))
        logger.addHandler(handler)
        logger.setLevel(logging.INFO)

from freqtrade.ml.lightning import LightningModule, LightningConfig
from freqtrade.ml.trainer import TradingTrainer
from freqtrade.ml.container import LightningContainer
from freqtrade.ml import loader, lightning_utils
from freqtrade.optimize.optimize_reports import text_table_add_metrics
from freqtrade.nbtools.preset import ConfigPreset
from freqtrade.nbtools.backtest import backtest, DataLoader
from freqtrade.nbtools.remote_utils import load_lightning_container, get_lightning_artifact_ver
from freqtrade.nbtools.helper import parse_function_body
from freqtrade.nbtools import plotting, configs
from freqtrade.nbtools.helper import free_mem
from freqtrade.nbtools.pairs import PAIRS_HIGHCAP_NONSTABLE

# Constants
PATH_MOUNT = Path.cwd().parent / "mount"
DATALOADER = DataLoader(max_n_datasets=5)

# Custom function
def string_templating(string: str, data: dict, strip_doublequotes=False):
    _string = deepcopy(string)
    """Replace [|key|] in string with data["key"] """
    for key, value in data.items():
        to_replace = "[|{}|]".format(key)
        if strip_doublequotes:
            to_replace = "\"[|{}|]\"".format(key)
        if to_replace not in string:
            raise Exception(f"Not found formatting with key '{key}'")
        _string = _string.replace(to_replace, str(value))
    return _string


def start_backtesting(strat_func, lightning_name: str, bt_type: str, version):
    PATH_LOCAL_DATADIR = PATH_MOUNT / "data"
    LIGHTNING_CONTAINER_NAME = lightning_name

    if version == "latest":
        version = get_lightning_artifact_ver(LIGHTNING_CONTAINER_NAME, LIGHTNING_CONTAINER_NAME)
        print(f"You are using LATEST ({version}) of '{LIGHTNING_CONTAINER_NAME}'")

    lightning_container = load_lightning_container(LIGHTNING_CONTAINER_NAME, LIGHTNING_CONTAINER_NAME, version=version)
    
    if bt_type == "val":
        timerange = lightning_utils.get_timerange_trainval(lightning_container)
    elif bt_type == "opt":
        timerange = lightning_utils.get_timerange_opt(lightning_container)
    elif bt_type == "test":
        timerange = lightning_utils.get_timerange_test(lightning_container)
    else:
        raise Exception(f"Unknown BT type: {bt_type}")
    
    preset = ConfigPreset(
        name=f"ml_{bt_type}_{LIGHTNING_CONTAINER_NAME}",
        config_dict = configs.DEFAULT,
        path_data=PATH_LOCAL_DATADIR,
        timerange=timerange
    )
    preset.overwrite_config(pairs=lightning_container.config.pairs)

    strategy_code = string_templating(
        parse_function_body(strat_func),
        data={
            "LIGHTNING_CONTAINER_NAME": LIGHTNING_CONTAINER_NAME,
            "VERSION": version
        }
    )
    stats, summary = backtest(preset, strategy_code, dataloader=DATALOADER)
    return stats, summary, preset

# %% [markdown]
# # Lightning Module

# %%
MINI_DATA = False  
# True if used for testing purposes


attr.s(repr=False)
class CatBoostModule(LightningModule):
    """ Template for LightningModule """
        
    def on_configure(self) -> LightningConfig:
        
        # This datetime can be replaced with datetime.now()
        now = datetime(2021, 9, 1)
        
        # Lighting Configuration
        config = LightningConfig(
            
            # Basic info
            name        = "15n60-catboost_l1",
            timeframe   = "15m",
            exchange    = "binance",
            
            # Train and validation datetime
            trainval_start  = datetime(2016, 1, 1),
            trainval_end    = now - timedelta(days=91),
            
            # Backtest Optimization datetime
            opt_start = now - timedelta(days=90),
            opt_end   = now - timedelta(days=46),
            
            # Unbiased Backtest datetime
            test_start = now - timedelta(days=45),
            test_end   = now,
            
            # Optional
            num_training_epochs = 20000,
            learning_rate = 0.015,
        )
        
        # Optional custom config attributes
        config.add_custom("num_future_candles", 4)
        config.add_custom("num_classification_classes", 5)
        config.add_custom("hardware", "GPU")
        
        return config
        
    def on_get_data_paths(self, cwd: Path, timeframe: str, exchange: str) -> List[Path]:
        """ Where your data is stored
        """
        path_data_exchange = cwd.parent / "mount" / "data" / exchange
        maximum_data = 999 if not MINI_DATA else 5
        
        return [
            datapath
            for datapath in list(path_data_exchange.glob(f"*-{timeframe}.json"))
            if datapath.name.split("-")[0].replace("_", "/")
            in PAIRS_HIGHCAP_NONSTABLE[:maximum_data]
        ]
    
    def on_add_features(self, df_onepair: pd.DataFrame) -> pd.DataFrame:
        """ On Add Features will be used in inference
        """
        import pandas_ta as pta
        
        # Start add features
        spaces = [4, 6, 8, 12, 16, 26, 50, 100]
        
        for i in spaces:
            # Basics
            df_onepair[f"ml_smadiff_{i}"] = (df_onepair['close'].rolling(i).mean() - df_onepair['close'])
            df_onepair[f"ml_std_{i}"] = df_onepair['close'].rolling(i).std()
            df_onepair[f"ml_ma_{i}"] = df_onepair['close'].pct_change(i).rolling(i).mean()
            
            # Volume Basics
            df_onepair[f"ml_volstd_{i}"] = df_onepair['volume'].rolling(i).std()
            df_onepair[f"ml_volma_{i}"] = df_onepair['volume'].pct_change(i).rolling(i).mean()
            
            # Technical Indicators
            df_onepair.ta.rsi(length=i, append=True)
            df_onepair.ta.trix(length=i, append=True)
            # df_onepair.ta.stochrsi(length=i, append=True)
            # df_onepair.ta.macd(fast=int(i/2), slow=i, signal=9, append=True)
            # df_onepair.ta.cmo(length=i, append=True)

        for i in range(1, 30):
            # Previous Close
            df_onepair[f"ml_prevclose_{i}"] = (df_onepair["close"].shift(i) - df_onepair["close"]) / df_onepair["close"]

        for i in range(1, 15):
            # Lookback Candles
            df_onepair[f"ml_prevhigh_{i}"] = (df_onepair["high"].shift(i) - df_onepair["high"]) / df_onepair["high"]
            df_onepair[f"ml_prevlow_{i}"] = (df_onepair["low"].shift(i) - df_onepair["low"]) / df_onepair["low"]
            # Lookback Volume
            df_onepair[f"ml_prevvol_{i}"] = (df_onepair["volume"].shift(i) - df_onepair["volume"]) / df_onepair["volume"]
        
        # TODO: pct change until nearest psychological point.
        # Example: First digit change 49.000 BTC to 50.000. is 1000 (1000 / current_price ~ 0.02)
        # If closer than lower point, don't calculate to the upper point. Example: 44k is closer to 4k. BUT NEGATIVE!
            
        df_onepair["ml_volume_pctchange"] = df_onepair['volume'].pct_change()
        df_onepair['ml_z_score_120'] = (
            (df_onepair["ml_ma_16"] - df_onepair["ml_ma_16"].rolling(21).mean() + 1e-9) / 
            (df_onepair["ml_ma_16"].rolling(21).std() + 1e-9)
        )
        
        return df_onepair
    
    def on_add_labels(self, df_onepair: pd.DataFrame) -> pd.DataFrame:
        """ Define the labels
        """
        future_price = df_onepair['close'].shift(-self.config.num_future_candles)
        ml_label = (future_price - df_onepair['close']) / df_onepair['close']
        df_onepair[self.config.column_y] = pd.qcut(ml_label, self.config.num_classification_classes, labels=False)
        return df_onepair
    
    def on_final_processing(self, df_allpairs: pd.DataFrame) -> Tuple[Any, Any, Any, Any]:
        """ Define the data to X_train, X_val, y_train, y_val
        """
        # val_split_date = pd.to_datetime(self.config.trainval_end - timedelta(days=60), utc=True, infer_datetime_format=True)
        
        # train = df_allpairs[df_allpairs["date"] < val_split_date]
        # val = df_allpairs[df_allpairs["date"] >= val_split_date]

        # print("Train start - end:", train["date"].min(), train["date"].max())
        # print("Val start - end:", val["date"].min(), val["date"].max())

        # X_train = train[self.config.columns_x]
        # X_val = val[self.config.columns_x]
        # y_train = train[self.config.column_y]
        # y_val = val[self.config.column_y]

        X = df_allpairs[self.config.columns_x]
        y = df_allpairs[self.config.column_y]
        X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=1)
    
        print("Num train datas:", len(X_train))
        print("Num val datas:", len(X_val))

        return X_train, X_val, y_train, y_val
    
    def on_define_model(self, run: Run, X_train, X_val, y_train, y_val) -> Any:
        """ Define your model!
        """
        return CatBoostClassifier(
            custom_loss=[metrics.Accuracy()],
            iterations=self.config.num_training_epochs, 
            task_type=self.config.hardware,
            learning_rate=self.config.learning_rate,
         )
    
    def on_start_training(self, run: Run, X_train, X_val, y_train, y_val):
        """ Training / model fit code
        """
        print("Start Training...")
        self.model: CatBoostClassifier
        self.model.fit(
            X_train, y_train,
            eval_set=(X_val, y_val),
            plot=True,
            verbose=1000,
        )
        print("Accuracy: %.4f" % self.model.score(X_val, y_val))
    
    def on_predict(self, df_input_onepair: pd.DataFrame) -> pd.DataFrame:
        """ Inference, used in freqtrade
        """
        df_input_np = df_input_onepair.to_numpy()
        preds = self.model.predict_proba(df_input_np)
        return pd.DataFrame(preds)
    
    def on_training_step(self, run: Run, data: dict):
        raise NotImplementedError()


module = CatBoostModule()
container = LightningContainer(module)
# Out:
# freqtrade.ml.container - Set up config
# INFO:freqtrade.ml.container:Set up config
# freqtrade.ml.container - {'name': '15n60-catboost_l1', 'timeframe': '15m', 'exchange': 'binance', 'trainval_start': datetime.datetime(2016, 1, 1, 0, 0), 'trainval_end': datetime.datetime(2021, 6, 2, 0, 0), 'opt_start': datetime.datetime(2021, 6, 3, 0, 0), 'opt_end': datetime.datetime(2021, 7, 17, 0, 0), 'test_start': datetime.datetime(2021, 7, 18, 0, 0), 'test_end': datetime.datetime(2021, 9, 1, 0, 0), 'num_training_epochs': 20000, 'learning_rate': 0.015, 'column_y': 'ml_label', 'columns_unused': ['date', 'open', 'high', 'low', 'close', 'volume', 'pair', 'ml_label'], 'columns_x': None, 'data_filenames': ['AAVE_USDT-15m.json', 'ADA_USDT-15m.json', 'ALGO_USDT-15m.json', 'ANKR_USDT-15m.json', 'ATOM_USDT-15m.json', 'AVAX_USDT-15m.json', 'BAT_USDT-15m.json', 'BCH_USDT-15m.json', 'BNT_USDT-15m.json', 'BTC_USDT-15m.json', 'BTT_USDT-15m.json', 'CHZ_USDT-15m.json', 'COMP_USDT-15m.json', 'CRV_USDT-15m.json', 'DASH_USDT-15m.json', 'DCR_USDT-15m.json', 'DOGE_USDT-15m.json', 'DOT_USDT-15m.json', 'EGLD_USDT-15m.json', 'ENJ_USDT-15m.json', 'EOS_USDT-15m.json', 'ETC_USDT-15m.json', 'ETH_USDT-15m.json', 'FIL_USDT-15m.json', 'FTM_USDT-15m.json', 'FTT_USDT-15m.json', 'HNT_USDT-15m.json', 'HOT_USDT-15m.json', 'ICX_USDT-15m.json', 'KSM_USDT-15m.json', 'LINK_USDT-15m.json', 'LTC_USDT-15m.json', 'LUNA_USDT-15m.json', 'MANA_USDT-15m.json', 'MATIC_USDT-15m.json', 'MKR_USDT-15m.json', 'NANO_USDT-15m.json', 'NEAR_USDT-15m.json', 'NEO_USDT-15m.json', 'OMG_USDT-15m.json', 'ONE_USDT-15m.json', 'ONT_USDT-15m.json', 'QTUM_USDT-15m.json', 'RVN_USDT-15m.json', 'SNX_USDT-15m.json', 'SOL_USDT-15m.json', 'SUSHI_USDT-15m.json', 'TFUEL_USDT-15m.json', 'THETA_USDT-15m.json', 'TRX_USDT-15m.json', 'UNI_USDT-15m.json', 'VET_USDT-15m.json', 'WAVES_USDT-15m.json', 'XEM_USDT-15m.json', 'XLM_USDT-15m.json', 'XMR_USDT-15m.json', 'XRP_USDT-15m.json', 'YFI_USDT-15m.json', 'ZEC_USDT-15m.json', 'ZIL_USDT-15m.json', 'ZRX_USDT-15m.json'], 'pairs': ['AAVE/USDT', 'ADA/USDT', 'ALGO/USDT', 'ANKR/USDT', 'ATOM/USDT', 'AVAX/USDT', 'BAT/USDT', 'BCH/USDT', 'BNT/USDT', 'BTC/USDT', 'BTT/USDT', 'CHZ/USDT', 'COMP/USDT', 'CRV/USDT', 'DASH/USDT', 'DCR/USDT', 'DOGE/USDT', 'DOT/USDT', 'EGLD/USDT', 'ENJ/USDT', 'EOS/USDT', 'ETC/USDT', 'ETH/USDT', 'FIL/USDT', 'FTM/USDT', 'FTT/USDT', 'HNT/USDT', 'HOT/USDT', 'ICX/USDT', 'KSM/USDT', 'LINK/USDT', 'LTC/USDT', 'LUNA/USDT', 'MANA/USDT', 'MATIC/USDT', 'MKR/USDT', 'NANO/USDT', 'NEAR/USDT', 'NEO/USDT', 'OMG/USDT', 'ONE/USDT', 'ONT/USDT', 'QTUM/USDT', 'RVN/USDT', 'SNX/USDT', 'SOL/USDT', 'SUSHI/USDT', 'TFUEL/USDT', 'THETA/USDT', 'TRX/USDT', 'UNI/USDT', 'VET/USDT', 'WAVES/USDT', 'XEM/USDT', 'XLM/USDT', 'XMR/USDT', 'XRP/USDT', 'YFI/USDT', 'ZEC/USDT', 'ZIL/USDT', 'ZRX/USDT'], 'extras': {'num_future_candles': 4, 'num_classification_classes': 5, 'hardware': 'GPU'}, 'num_future_candles': 4, 'num_classification_classes': 5, 'hardware': 'GPU'}
# INFO:freqtrade.ml.container:{'name': '15n60-catboost_l1', 'timeframe': '15m', 'exchange': 'binance', 'trainval_start': datetime.datetime(2016, 1, 1, 0, 0), 'trainval_end': datetime.datetime(2021, 6, 2, 0, 0), 'opt_start': datetime.datetime(2021, 6, 3, 0, 0), 'opt_end': datetime.datetime(2021, 7, 17, 0, 0), 'test_start': datetime.datetime(2021, 7, 18, 0, 0), 'test_end': datetime.datetime(2021, 9, 1, 0, 0), 'num_training_epochs': 20000, 'learning_rate': 0.015, 'column_y': 'ml_label', 'columns_unused': ['date', 'open', 'high', 'low', 'close', 'volume', 'pair', 'ml_label'], 'columns_x': None, 'data_filenames': ['AAVE_USDT-15m.json', 'ADA_USDT-15m.json', 'ALGO_USDT-15m.json', 'ANKR_USDT-15m.json', 'ATOM_USDT-15m.json', 'AVAX_USDT-15m.json', 'BAT_USDT-15m.json', 'BCH_USDT-15m.json', 'BNT_USDT-15m.json', 'BTC_USDT-15m.json', 'BTT_USDT-15m.json', 'CHZ_USDT-15m.json', 'COMP_USDT-15m.json', 'CRV_USDT-15m.json', 'DASH_USDT-15m.json', 'DCR_USDT-15m.json', 'DOGE_USDT-15m.json', 'DOT_USDT-15m.json', 'EGLD_USDT-15m.json', 'ENJ_USDT-15m.json', 'EOS_USDT-15m.json', 'ETC_USDT-15m.json', 'ETH_USDT-15m.json', 'FIL_USDT-15m.json', 'FTM_USDT-15m.json', 'FTT_USDT-15m.json', 'HNT_USDT-15m.json', 'HOT_USDT-15m.json', 'ICX_USDT-15m.json', 'KSM_USDT-15m.json', 'LINK_USDT-15m.json', 'LTC_USDT-15m.json', 'LUNA_USDT-15m.json', 'MANA_USDT-15m.json', 'MATIC_USDT-15m.json', 'MKR_USDT-15m.json', 'NANO_USDT-15m.json', 'NEAR_USDT-15m.json', 'NEO_USDT-15m.json', 'OMG_USDT-15m.json', 'ONE_USDT-15m.json', 'ONT_USDT-15m.json', 'QTUM_USDT-15m.json', 'RVN_USDT-15m.json', 'SNX_USDT-15m.json', 'SOL_USDT-15m.json', 'SUSHI_USDT-15m.json', 'TFUEL_USDT-15m.json', 'THETA_USDT-15m.json', 'TRX_USDT-15m.json', 'UNI_USDT-15m.json', 'VET_USDT-15m.json', 'WAVES_USDT-15m.json', 'XEM_USDT-15m.json', 'XLM_USDT-15m.json', 'XMR_USDT-15m.json', 'XRP_USDT-15m.json', 'YFI_USDT-15m.json', 'ZEC_USDT-15m.json', 'ZIL_USDT-15m.json', 'ZRX_USDT-15m.json'], 'pairs': ['AAVE/USDT', 'ADA/USDT', 'ALGO/USDT', 'ANKR/USDT', 'ATOM/USDT', 'AVAX/USDT', 'BAT/USDT', 'BCH/USDT', 'BNT/USDT', 'BTC/USDT', 'BTT/USDT', 'CHZ/USDT', 'COMP/USDT', 'CRV/USDT', 'DASH/USDT', 'DCR/USDT', 'DOGE/USDT', 'DOT/USDT', 'EGLD/USDT', 'ENJ/USDT', 'EOS/USDT', 'ETC/USDT', 'ETH/USDT', 'FIL/USDT', 'FTM/USDT', 'FTT/USDT', 'HNT/USDT', 'HOT/USDT', 'ICX/USDT', 'KSM/USDT', 'LINK/USDT', 'LTC/USDT', 'LUNA/USDT', 'MANA/USDT', 'MATIC/USDT', 'MKR/USDT', 'NANO/USDT', 'NEAR/USDT', 'NEO/USDT', 'OMG/USDT', 'ONE/USDT', 'ONT/USDT', 'QTUM/USDT', 'RVN/USDT', 'SNX/USDT', 'SOL/USDT', 'SUSHI/USDT', 'TFUEL/USDT', 'THETA/USDT', 'TRX/USDT', 'UNI/USDT', 'VET/USDT', 'WAVES/USDT', 'XEM/USDT', 'XLM/USDT', 'XMR/USDT', 'XRP/USDT', 'YFI/USDT', 'ZEC/USDT', 'ZIL/USDT', 'ZRX/USDT'], 'extras': {'num_future_candles': 4, 'num_classification_classes': 5, 'hardware': 'GPU'}, 'num_future_candles': 4, 'num_classification_classes': 5, 'hardware': 'GPU'}

# %% [markdown]
# # Dataset EDA Before Training

# %%
df_: pd.DataFrame = lightning_utils.get_dataset_df(container)
X_train, X_val, y_train, y_val = container.final_processing(df_)
dates = df_["date"]
df_ = df_[module.config.columns_x + [module.config.column_y]]
df_.tail()
# Out:
# Load and preprocess data:   0%|          | 0/61 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31464/4270084009.py in <module>
# ----> 1 df_: pd.DataFrame = lightning_utils.get_dataset_df(container)
#       2 X_train, X_val, y_train, y_val = container.final_processing(df_)
#       3 dates = df_["date"]
#       4 df_ = df_[module.config.columns_x + [module.config.column_y]]
#       5 df_.tail()
#
# c:\CS\Python\crypto-collection\freqtrade\superft\freqtrade\ml\lightning_utils.py in get_dataset_df(container)
#      31     if not isinstance(container, LightningContainer):
#      32         return LightningContainer(container)._load_df_allpairs()
# ---> 33     return container._load_df_allpairs()
#
# c:\CS\Python\crypto-collection\freqtrade\superft\freqtrade\ml\container.py in _load_df_allpairs(self)
#      65
#      66         sys.path.append(str(Path(__file__).parent.parent.parent))
# ---> 67         df_list = Parallel(n_jobs=8, prefer="processes")(
#      68             delayed(self._load_one)(path) for path in progress(paths, desc="Load and preprocess data")
#      69         )
#
# ~\.virtualenvs\freqtrade-futures\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~\.virtualenvs\freqtrade-futures\lib\site-packages\joblib\parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# ~\.virtualenvs\freqtrade-futures\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# C:\Python\Python39\lib\concurrent\futures\_base.py in result(self, timeout)
#     438                     return self.__get_result()
#     439
# --> 440                 self._condition.wait(timeout)
#     441
#     442                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# C:\Python\Python39\lib\threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %%
print(list(df_.columns))
print(f"Total features: {len(list(df_.columns))}")
# Out:
# ['ml_smadiff_4', 'ml_std_4', 'ml_ma_4', 'ml_volstd_4', 'ml_volma_4', 'MACD_2_4_9', 'MACDh_2_4_9', 'MACDs_2_4_9', 'RSI_4', 'CMO_4', 'STOCHRSIk_4_14_3_3', 'STOCHRSId_4_14_3_3', 'TRIX_4_9', 'TRIXs_4_9', 'ml_smadiff_6', 'ml_std_6', 'ml_ma_6', 'ml_volstd_6', 'ml_volma_6', 'MACD_3_6_9', 'MACDh_3_6_9', 'MACDs_3_6_9', 'RSI_6', 'CMO_6', 'STOCHRSIk_6_14_3_3', 'STOCHRSId_6_14_3_3', 'TRIX_6_9', 'TRIXs_6_9', 'ml_smadiff_8', 'ml_std_8', 'ml_ma_8', 'ml_volstd_8', 'ml_volma_8', 'MACD_4_8_9', 'MACDh_4_8_9', 'MACDs_4_8_9', 'RSI_8', 'CMO_8', 'STOCHRSIk_8_14_3_3', 'STOCHRSId_8_14_3_3', 'TRIX_8_9', 'TRIXs_8_9', 'ml_smadiff_12', 'ml_std_12', 'ml_ma_12', 'ml_volstd_12', 'ml_volma_12', 'MACD_6_12_9', 'MACDh_6_12_9', 'MACDs_6_12_9', 'RSI_12', 'CMO_12', 'STOCHRSIk_12_14_3_3', 'STOCHRSId_12_14_3_3', 'TRIX_12_9', 'TRIXs_12_9', 'ml_smadiff_16', 'ml_std_16', 'ml_ma_16', 'ml_volstd_16', 'ml_volma_16', 'MACD_8_16_9', 'MACDh_8_16_9', 'MACDs_8_16_9', 'RSI_16', 'CMO_16', 'STOCHRSIk_16_14_3_3', 'STOCHRSId_16_14_3_3', 'TRIX_16_9', 'TRIXs_16_9', 'ml_smadiff_26', 'ml_std_26', 'ml_ma_26', 'ml_volstd_26', 'ml_volma_26', 'MACD_13_26_9', 'MACDh_13_26_9', 'MACDs_13_26_9', 'RSI_26', 'CMO_26', 'STOCHRSIk_26_14_3_3', 'STOCHRSId_26_14_3_3', 'TRIX_26_9', 'TRIXs_26_9', 'ml_smadiff_50', 'ml_std_50', 'ml_ma_50', 'ml_volstd_50', 'ml_volma_50', 'MACD_25_50_9', 'MACDh_25_50_9', 'MACDs_25_50_9', 'RSI_50', 'CMO_50', 'STOCHRSIk_50_14_3_3', 'STOCHRSId_50_14_3_3', 'TRIX_50_9', 'TRIXs_50_9', 'ml_smadiff_100', 'ml_std_100', 'ml_ma_100', 'ml_volstd_100', 'ml_volma_100', 'MACD_50_100_9', 'MACDh_50_100_9', 'MACDs_50_100_9', 'RSI_100', 'CMO_100', 'STOCHRSIk_100_14_3_3', 'STOCHRSId_100_14_3_3', 'TRIX_100_9', 'TRIXs_100_9', 'ml_smadiff_200', 'ml_std_200', 'ml_ma_200', 'ml_volstd_200', 'ml_volma_200', 'MACD_100_200_9', 'MACDh_100_200_9', 'MACDs_100_200_9', 'RSI_200', 'CMO_200', 'STOCHRSIk_200_14_3_3', 'STOCHRSId_200_14_3_3', 'TRIX_200_9', 'TRIXs_200_9', 'ml_prevclose_1', 'ml_prevhigh_1', 'ml_prevlow_1', 'ml_prevopen_1', 'ml_prevvol_1', 'ml_prevclose_2', 'ml_prevhigh_2', 'ml_prevlow_2', 'ml_prevopen_2', 'ml_prevvol_2', 'ml_prevclose_3', 'ml_prevhigh_3', 'ml_prevlow_3', 'ml_prevopen_3', 'ml_prevvol_3', 'ml_prevclose_4', 'ml_prevhigh_4', 'ml_prevlow_4', 'ml_prevopen_4', 'ml_prevvol_4', 'ml_prevclose_5', 'ml_prevhigh_5', 'ml_prevlow_5', 'ml_prevopen_5', 'ml_prevvol_5', 'ml_prevclose_6', 'ml_prevhigh_6', 'ml_prevlow_6', 'ml_prevopen_6', 'ml_prevvol_6', 'ml_prevclose_7', 'ml_prevhigh_7', 'ml_prevlow_7', 'ml_prevopen_7', 'ml_prevvol_7', 'ml_prevclose_8', 'ml_prevhigh_8', 'ml_prevlow_8', 'ml_prevopen_8', 'ml_prevvol_8', 'ml_prevclose_9', 'ml_prevhigh_9', 'ml_prevlow_9', 'ml_prevopen_9', 'ml_prevvol_9', 'ml_prevclose_10', 'ml_prevhigh_10', 'ml_prevlow_10', 'ml_prevopen_10', 'ml_prevvol_10', 'ml_volume_pctchange', 'ml_z_score_120', 'ml_label']
# Total features: 179

# %%
def dataframe_statistics(df_: pd.DataFrame):
    # Detect nan, infinity, and too large values in dataset
    print("N rows na:", str(df_.shape[0] - df_.dropna().shape[0]))
    print("N rows inf:", str(df_.shape[0] - df_.replace([np.inf, -np.inf], np.nan).dropna().shape[0]))
    print("Cols na:", str(df_.columns[df_.isna().any()].tolist()))
    print("Cols inf:", str(list(df_.columns.to_series()[np.isinf(df_).any()])))

    # Detect columns with irregular datatypes
    supported_datatypes = ["float32"]
    print("Irregular (col, dtypes):", str([(it, df_[it].dtype) for it in df_.columns if df_[it].dtype not in supported_datatypes]))

    # Dataset statistics
    print("Dataset Length: %s" % len(df_))
    print("Date Min: %s" % dates.min())
    print("Date Max: %s" % dates.max())
    
dataframe_statistics(df_)
# Out:
# N rows na: 0
# N rows inf: 0
# Cols na: []
# Cols inf: []
# Irregular (col, dtypes): []
# Dataset Length: 491793
# Date Min: 2017-08-26 09:45:00+00:00
# Date Max: 2021-06-01 23:30:00+00:00

# %%
df_["ml_label"].hist()
# Out:
# <AxesSubplot:>

# %%
# Unload dataset after EDA to save memory
free_mem(df_)

# %% [markdown]
# # [-Start Training-]

# %%
with wandb.init(project=module.config.name) as run:
    trainer = TradingTrainer()
    container = trainer.fit(module, run, True)
# Out:
# freqtrade.ml.container - Set up config
# INFO:freqtrade.ml.container:Set up config
# freqtrade.ml.container - {'name': '15n60-catboost_l1', 'timeframe': '15m', 'exchange': 'binance', 'trainval_start': datetime.datetime(2016, 1, 1, 0, 0), 'trainval_end': datetime.datetime(2021, 6, 2, 0, 0), 'opt_start': datetime.datetime(2021, 6, 3, 0, 0), 'opt_end': datetime.datetime(2021, 7, 17, 0, 0), 'test_start': datetime.datetime(2021, 7, 18, 0, 0), 'test_end': datetime.datetime(2021, 9, 1, 0, 0), 'num_training_epochs': 20000, 'learning_rate': 0.015, 'column_y': 'ml_label', 'columns_unused': ['date', 'open', 'high', 'low', 'close', 'volume', 'pair', 'ml_label'], 'columns_x': None, 'data_filenames': ['AAVE_USDT-15m.json', 'ADA_USDT-15m.json', 'ALGO_USDT-15m.json', 'ANKR_USDT-15m.json', 'ATOM_USDT-15m.json', 'AVAX_USDT-15m.json', 'BAT_USDT-15m.json', 'BCH_USDT-15m.json', 'BNT_USDT-15m.json', 'BTC_USDT-15m.json', 'BTT_USDT-15m.json', 'CHZ_USDT-15m.json', 'COMP_USDT-15m.json', 'CRV_USDT-15m.json', 'DASH_USDT-15m.json', 'DCR_USDT-15m.json', 'DOGE_USDT-15m.json', 'DOT_USDT-15m.json', 'EGLD_USDT-15m.json', 'ENJ_USDT-15m.json', 'EOS_USDT-15m.json', 'ETC_USDT-15m.json', 'ETH_USDT-15m.json', 'FIL_USDT-15m.json', 'FTM_USDT-15m.json', 'FTT_USDT-15m.json', 'HNT_USDT-15m.json', 'HOT_USDT-15m.json', 'ICX_USDT-15m.json', 'KSM_USDT-15m.json', 'LINK_USDT-15m.json', 'LTC_USDT-15m.json', 'LUNA_USDT-15m.json', 'MANA_USDT-15m.json', 'MATIC_USDT-15m.json', 'MKR_USDT-15m.json', 'NANO_USDT-15m.json', 'NEAR_USDT-15m.json', 'NEO_USDT-15m.json', 'OMG_USDT-15m.json', 'ONE_USDT-15m.json', 'ONT_USDT-15m.json', 'QTUM_USDT-15m.json', 'RVN_USDT-15m.json', 'SNX_USDT-15m.json', 'SOL_USDT-15m.json', 'SUSHI_USDT-15m.json', 'TFUEL_USDT-15m.json', 'THETA_USDT-15m.json', 'TRX_USDT-15m.json', 'UNI_USDT-15m.json', 'VET_USDT-15m.json', 'WAVES_USDT-15m.json', 'XEM_USDT-15m.json', 'XLM_USDT-15m.json', 'XMR_USDT-15m.json', 'XRP_USDT-15m.json', 'YFI_USDT-15m.json', 'ZEC_USDT-15m.json', 'ZIL_USDT-15m.json', 'ZRX_USDT-15m.json'], 'pairs': ['AAVE/USDT', 'ADA/USDT', 'ALGO/USDT', 'ANKR/USDT', 'ATOM/USDT', 'AVAX/USDT', 'BAT/USDT', 'BCH/USDT', 'BNT/USDT', 'BTC/USDT', 'BTT/USDT', 'CHZ/USDT', 'COMP/USDT', 'CRV/USDT', 'DASH/USDT', 'DCR/USDT', 'DOGE/USDT', 'DOT/USDT', 'EGLD/USDT', 'ENJ/USDT', 'EOS/USDT', 'ETC/USDT', 'ETH/USDT', 'FIL/USDT', 'FTM/USDT', 'FTT/USDT', 'HNT/USDT', 'HOT/USDT', 'ICX/USDT', 'KSM/USDT', 'LINK/USDT', 'LTC/USDT', 'LUNA/USDT', 'MANA/USDT', 'MATIC/USDT', 'MKR/USDT', 'NANO/USDT', 'NEAR/USDT', 'NEO/USDT', 'OMG/USDT', 'ONE/USDT', 'ONT/USDT', 'QTUM/USDT', 'RVN/USDT', 'SNX/USDT', 'SOL/USDT', 'SUSHI/USDT', 'TFUEL/USDT', 'THETA/USDT', 'TRX/USDT', 'UNI/USDT', 'VET/USDT', 'WAVES/USDT', 'XEM/USDT', 'XLM/USDT', 'XMR/USDT', 'XRP/USDT', 'YFI/USDT', 'ZEC/USDT', 'ZIL/USDT', 'ZRX/USDT'], 'extras': {'num_future_candles': 4, 'num_classification_classes': 5, 'hardware': 'GPU'}, 'num_future_candles': 4, 'num_classification_classes': 5, 'hardware': 'GPU'}
# INFO:freqtrade.ml.container:{'name': '15n60-catboost_l1', 'timeframe': '15m', 'exchange': 'binance', 'trainval_start': datetime.datetime(2016, 1, 1, 0, 0), 'trainval_end': datetime.datetime(2021, 6, 2, 0, 0), 'opt_start': datetime.datetime(2021, 6, 3, 0, 0), 'opt_end': datetime.datetime(2021, 7, 17, 0, 0), 'test_start': datetime.datetime(2021, 7, 18, 0, 0), 'test_end': datetime.datetime(2021, 9, 1, 0, 0), 'num_training_epochs': 20000, 'learning_rate': 0.015, 'column_y': 'ml_label', 'columns_unused': ['date', 'open', 'high', 'low', 'close', 'volume', 'pair', 'ml_label'], 'columns_x': None, 'data_filenames': ['AAVE_USDT-15m.json', 'ADA_USDT-15m.json', 'ALGO_USDT-15m.json', 'ANKR_USDT-15m.json', 'ATOM_USDT-15m.json', 'AVAX_USDT-15m.json', 'BAT_USDT-15m.json', 'BCH_USDT-15m.json', 'BNT_USDT-15m.json', 'BTC_USDT-15m.json', 'BTT_USDT-15m.json', 'CHZ_USDT-15m.json', 'COMP_USDT-15m.json', 'CRV_USDT-15m.json', 'DASH_USDT-15m.json', 'DCR_USDT-15m.json', 'DOGE_USDT-15m.json', 'DOT_USDT-15m.json', 'EGLD_USDT-15m.json', 'ENJ_USDT-15m.json', 'EOS_USDT-15m.json', 'ETC_USDT-15m.json', 'ETH_USDT-15m.json', 'FIL_USDT-15m.json', 'FTM_USDT-15m.json', 'FTT_USDT-15m.json', 'HNT_USDT-15m.json', 'HOT_USDT-15m.json', 'ICX_USDT-15m.json', 'KSM_USDT-15m.json', 'LINK_USDT-15m.json', 'LTC_USDT-15m.json', 'LUNA_USDT-15m.json', 'MANA_USDT-15m.json', 'MATIC_USDT-15m.json', 'MKR_USDT-15m.json', 'NANO_USDT-15m.json', 'NEAR_USDT-15m.json', 'NEO_USDT-15m.json', 'OMG_USDT-15m.json', 'ONE_USDT-15m.json', 'ONT_USDT-15m.json', 'QTUM_USDT-15m.json', 'RVN_USDT-15m.json', 'SNX_USDT-15m.json', 'SOL_USDT-15m.json', 'SUSHI_USDT-15m.json', 'TFUEL_USDT-15m.json', 'THETA_USDT-15m.json', 'TRX_USDT-15m.json', 'UNI_USDT-15m.json', 'VET_USDT-15m.json', 'WAVES_USDT-15m.json', 'XEM_USDT-15m.json', 'XLM_USDT-15m.json', 'XMR_USDT-15m.json', 'XRP_USDT-15m.json', 'YFI_USDT-15m.json', 'ZEC_USDT-15m.json', 'ZIL_USDT-15m.json', 'ZRX_USDT-15m.json'], 'pairs': ['AAVE/USDT', 'ADA/USDT', 'ALGO/USDT', 'ANKR/USDT', 'ATOM/USDT', 'AVAX/USDT', 'BAT/USDT', 'BCH/USDT', 'BNT/USDT', 'BTC/USDT', 'BTT/USDT', 'CHZ/USDT', 'COMP/USDT', 'CRV/USDT', 'DASH/USDT', 'DCR/USDT', 'DOGE/USDT', 'DOT/USDT', 'EGLD/USDT', 'ENJ/USDT', 'EOS/USDT', 'ETC/USDT', 'ETH/USDT', 'FIL/USDT', 'FTM/USDT', 'FTT/USDT', 'HNT/USDT', 'HOT/USDT', 'ICX/USDT', 'KSM/USDT', 'LINK/USDT', 'LTC/USDT', 'LUNA/USDT', 'MANA/USDT', 'MATIC/USDT', 'MKR/USDT', 'NANO/USDT', 'NEAR/USDT', 'NEO/USDT', 'OMG/USDT', 'ONE/USDT', 'ONT/USDT', 'QTUM/USDT', 'RVN/USDT', 'SNX/USDT', 'SOL/USDT', 'SUSHI/USDT', 'TFUEL/USDT', 'THETA/USDT', 'TRX/USDT', 'UNI/USDT', 'VET/USDT', 'WAVES/USDT', 'XEM/USDT', 'XLM/USDT', 'XMR/USDT', 'XRP/USDT', 'YFI/USDT', 'ZEC/USDT', 'ZIL/USDT', 'ZRX/USDT'], 'extras': {'num_future_candles': 4, 'num_classification_classes': 5, 'hardware': 'GPU'}, 'num_future_candles': 4, 'num_classification_classes': 5, 'hardware': 'GPU'}
# freqtrade.ml.trainer - Validating model using mini training...
# INFO:freqtrade.ml.trainer:Validating model using mini training...
# Load and preprocess data:   0%|          | 0/1 [00:00<?, ?it/s]
# Num train datas: 98929
# Num val datas: 24733
# Start Training...
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 1.6068588	test: 1.6068272	best: 1.6068272 (0)	total: 22.4ms	remaining: 201ms
# 9:	learn: 1.5864465	test: 1.5861479	best: 1.5861479 (9)	total: 179ms	remaining: 0us
# bestTest = 1.586147872
# bestIteration = 9
# Accuracy: 0.3203
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevlow_{i}"] = (df_onepair["low"].shift(i) - df_onepair["low"]) / df_onepair["low"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevopen_{i}"] = (df_onepair["open"].shift(i) - df_onepair["open"]) / df_onepair["open"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevvol_{i}"] = (df_onepair["volume"].shift(i) - df_onepair["volume"]) / df_onepair["volume"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:90: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevhigh_{i}"] = (df_onepair["high"].shift(i) - df_onepair["high"]) / df_onepair["high"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:100: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair["ml_volume_pctchange"] = df_onepair['volume'].pct_change()
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:101: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair['ml_z_score_120'] = (
# PASSED: The model passed the validation test!
# freqtrade.ml.trainer - Validate model OK!
# INFO:freqtrade.ml.trainer:Validate model OK!
# Load and preprocess data:   0%|          | 0/61 [00:00<?, ?it/s]
# Num train datas: 2595223
# Num val datas: 648806
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevlow_{i}"] = (df_onepair["low"].shift(i) - df_onepair["low"]) / df_onepair["low"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevopen_{i}"] = (df_onepair["open"].shift(i) - df_onepair["open"]) / df_onepair["open"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevvol_{i}"] = (df_onepair["volume"].shift(i) - df_onepair["volume"]) / df_onepair["volume"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:90: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevhigh_{i}"] = (df_onepair["high"].shift(i) - df_onepair["high"]) / df_onepair["high"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:100: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair["ml_volume_pctchange"] = df_onepair['volume'].pct_change()
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:101: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair['ml_z_score_120'] = (
# WARNING:root:ERROR on validating predict function: `There is no trained model to use predict_proba(). Use fit() to train model. Then use this method.`
# WARNING:root:Please run `trainer.validate_predict()` after training finished!
# WARNING:root:Otherwise, future runtime errors may occur.
# Start Training...
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 1.6082303	test: 1.6082005	best: 1.6082005 (0)	total: 77.6ms	remaining: 25m 52s
# 1000:	learn: 1.5290424	test: 1.5308559	best: 1.5308559 (1000)	total: 1m 11s	remaining: 22m 41s
# 2000:	learn: 1.5223272	test: 1.5256955	best: 1.5256955 (2000)	total: 2m 25s	remaining: 21m 46s
# 3000:	learn: 1.5177431	test: 1.5226636	best: 1.5226636 (3000)	total: 3m 39s	remaining: 20m 42s
# 4000:	learn: 1.5140118	test: 1.5204598	best: 1.5204598 (4000)	total: 4m 53s	remaining: 19m 31s
# 5000:	learn: 1.5107257	test: 1.5187046	best: 1.5187046 (5000)	total: 6m 5s	remaining: 18m 15s
# 6000:	learn: 1.5077303	test: 1.5172146	best: 1.5172142 (5999)	total: 7m 16s	remaining: 16m 57s
# 7000:	learn: 1.5049213	test: 1.5159143	best: 1.5159143 (7000)	total: 8m 28s	remaining: 15m 44s
# 8000:	learn: 1.5022694	test: 1.5147646	best: 1.5147646 (8000)	total: 9m 58s	remaining: 14m 58s
# 9000:	learn: 1.4997485	test: 1.5137147	best: 1.5137139 (8999)	total: 11m 11s	remaining: 13m 41s
# 10000:	learn: 1.4973071	test: 1.5127584	best: 1.5127574 (9998)	total: 12m 23s	remaining: 12m 23s
# 11000:	learn: 1.4949204	test: 1.5118461	best: 1.5118458 (10999)	total: 13m 34s	remaining: 11m 6s
# 12000:	learn: 1.4925939	test: 1.5109982	best: 1.5109978 (11999)	total: 14m 46s	remaining: 9m 50s
# 13000:	learn: 1.4903657	test: 1.5102021	best: 1.5102021 (13000)	total: 15m 57s	remaining: 8m 35s
# 14000:	learn: 1.4881732	test: 1.5094450	best: 1.5094450 (14000)	total: 17m 8s	remaining: 7m 20s
# 15000:	learn: 1.4860427	test: 1.5087394	best: 1.5087394 (15000)	total: 18m 19s	remaining: 6m 6s
# 16000:	learn: 1.4839532	test: 1.5080613	best: 1.5080606 (15999)	total: 19m 28s	remaining: 4m 52s
# 17000:	learn: 1.4818716	test: 1.5074020	best: 1.5074019 (16999)	total: 20m 38s	remaining: 3m 38s
# 18000:	learn: 1.4798536	test: 1.5067998	best: 1.5067998 (18000)	total: 21m 47s	remaining: 2m 25s
# 19000:	learn: 1.4778377	test: 1.5062095	best: 1.5062087 (18998)	total: 22m 57s	remaining: 1m 12s
# 19999:	learn: 1.4758818	test: 1.5056420	best: 1.5056420 (19999)	total: 24m 7s	remaining: 0us
# bestTest = 1.505641999
# bestIteration = 19999
# Accuracy: 0.3252

# %% [markdown]
# # Predictions EDA

# %%
# Validate prediction function by simulate inserting freqtrade data into predict function
df_val_preds = trainer.validate_predict(container)
df_val_preds
# Out:
# freqtrade.ml.container - Not dropping X columns in predict because it doesn't exist in predict columns
# INFO:freqtrade.ml.container:Not dropping X columns in predict because it doesn't exist in predict columns
# freqtrade.ml.container - Returned new columns from df_preds: ['ml_0', 'ml_1', 'ml_2', 'ml_3', 'ml_4']
# INFO:freqtrade.ml.container:Returned new columns from df_preds: ['ml_0', 'ml_1', 'ml_2', 'ml_3', 'ml_4']
# Dataset: Binance BTC/USDT 15m iloc[-10000:] (Freqtrade Regularized)
#
#
# DF WITH PREDICTIONS INFO
# ----------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 131026 to 141025
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    10000 non-null  datetime64[ns, UTC]
#  1   open    10000 non-null  float64
#  2   high    10000 non-null  float64
#  3   low     10000 non-null  float64
#  4   close   10000 non-null  float64
#  5   volume  10000 non-null  float64
#  6   ml_0    9185 non-null   float64
#  7   ml_1    9185 non-null   float64
#  8   ml_2    9185 non-null   float64
#  9   ml_3    9185 non-null   float64
#  10  ml_4    9185 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(10)
# memory usage: 937.5 KB
# None
#
#
# DF Original
# ----------
#                             date      open      high       low     close  \
# 131026 2021-05-13 00:30:00+00:00  49711.83  50630.00  49578.94  49896.61
# 131027 2021-05-13 00:45:00+00:00  49896.15  50324.72  49581.44  49666.99
# 131028 2021-05-13 01:00:00+00:00  49661.12  50600.00  49305.43  50191.47
# 131029 2021-05-13 01:15:00+00:00  50191.47  50437.86  49972.44  50324.12
# 131030 2021-05-13 01:30:00+00:00  50314.99  50374.48  49665.94  49889.82
# ...                          ...       ...       ...       ...       ...
# 141021 2021-08-25 03:15:00+00:00  48135.89  48274.85  48117.73  48250.65
# 141022 2021-08-25 03:30:00+00:00  48250.65  48275.00  48132.05  48191.09
# 141023 2021-08-25 03:45:00+00:00  48191.08  48248.23  47965.00  47975.93
# 141024 2021-08-25 04:00:00+00:00  47975.93  48245.00  47940.02  48155.56
# 141025 2021-08-25 04:15:00+00:00  48155.56  48230.00  47964.34  47978.77
#
#              volume
# 131026  5110.913916
# 131027  2389.969100
# 131028  3869.211034
# 131029  2755.398561
# 131030  2116.566505
# ...             ...
# 141021   211.447645
# 141022   194.839454
# 141023   344.786940
# 141024   275.930495
# 141025   304.607179
#
# [10000 rows x 6 columns]
#
#
# DF + Preds
# ----------
#                             date      open      high       low     close  \
# 131026 2021-05-13 00:30:00+00:00  49711.83  50630.00  49578.94  49896.61
# 131027 2021-05-13 00:45:00+00:00  49896.15  50324.72  49581.44  49666.99
# 131028 2021-05-13 01:00:00+00:00  49661.12  50600.00  49305.43  50191.47
# 131029 2021-05-13 01:15:00+00:00  50191.47  50437.86  49972.44  50324.12
# 131030 2021-05-13 01:30:00+00:00  50314.99  50374.48  49665.94  49889.82
# ...                          ...       ...       ...       ...       ...
# 141021 2021-08-25 03:15:00+00:00  48135.89  48274.85  48117.73  48250.65
# 141022 2021-08-25 03:30:00+00:00  48250.65  48275.00  48132.05  48191.09
# 141023 2021-08-25 03:45:00+00:00  48191.08  48248.23  47965.00  47975.93
# 141024 2021-08-25 04:00:00+00:00  47975.93  48245.00  47940.02  48155.56
# 141025 2021-08-25 04:15:00+00:00  48155.56  48230.00  47964.34  47978.77
#
#              volume      ml_0      ml_1      ml_2      ml_3      ml_4
# 131026  5110.913916       NaN       NaN       NaN       NaN       NaN
# 131027  2389.969100       NaN       NaN       NaN       NaN       NaN
# 131028  3869.211034       NaN       NaN       NaN       NaN       NaN
# 131029  2755.398561       NaN       NaN       NaN       NaN       NaN
# 131030  2116.566505       NaN       NaN       NaN       NaN       NaN
# ...             ...       ...       ...       ...       ...       ...
# 141021   211.447645  0.201529  0.255884  0.202371  0.166218  0.173998
# 141022   194.839454  0.186121  0.231312  0.211827  0.196422  0.174319
# 141023   344.786940  0.237812  0.162050  0.153346  0.197669  0.249123
# 141024   275.930495  0.233152  0.200926  0.174560  0.174439  0.216924
# 141025   304.607179  0.233197  0.167416  0.162873  0.196231  0.240283
#
# [10000 rows x 11 columns]
#
#
# Vanilla Prediction [MAKE SURE SAME WITH PREDICTION DF!]
# ----------
#              0         1         2         3         4
# 0     0.358041  0.073891  0.054471  0.072139  0.441457
# 1     0.320938  0.059769  0.040835  0.058119  0.520339
# 2     0.378979  0.097949  0.069442  0.080402  0.373229
# 3     0.369821  0.067685  0.042813  0.060086  0.459594
# 4     0.341592  0.058220  0.037627  0.054436  0.508125
# ...        ...       ...       ...       ...       ...
# 9180  0.201529  0.255884  0.202371  0.166218  0.173998
# 9181  0.186121  0.231312  0.211827  0.196422  0.174319
# 9182  0.237812  0.162050  0.153346  0.197669  0.249123
# 9183  0.233152  0.200926  0.174560  0.174439  0.216924
# 9184  0.233197  0.167416  0.162873  0.196231  0.240283
#
# [9185 rows x 5 columns]
#
# LEN VANILLA PREDS: 9185
# LEN DF + PREDS NON NAN: 9185
#
# PASSED: The model passed the validation test!
#                             date      open      high       low     close  \
# 131026 2021-05-13 00:30:00+00:00  49711.83  50630.00  49578.94  49896.61
# 131027 2021-05-13 00:45:00+00:00  49896.15  50324.72  49581.44  49666.99
# 131028 2021-05-13 01:00:00+00:00  49661.12  50600.00  49305.43  50191.47
# 131029 2021-05-13 01:15:00+00:00  50191.47  50437.86  49972.44  50324.12
# 131030 2021-05-13 01:30:00+00:00  50314.99  50374.48  49665.94  49889.82
# ...                          ...       ...       ...       ...       ...
# 141021 2021-08-25 03:15:00+00:00  48135.89  48274.85  48117.73  48250.65
# 141022 2021-08-25 03:30:00+00:00  48250.65  48275.00  48132.05  48191.09
# 141023 2021-08-25 03:45:00+00:00  48191.08  48248.23  47965.00  47975.93
# 141024 2021-08-25 04:00:00+00:00  47975.93  48245.00  47940.02  48155.56
# 141025 2021-08-25 04:15:00+00:00  48155.56  48230.00  47964.34  47978.77
#
#              volume      ml_0      ml_1      ml_2      ml_3      ml_4
# 131026  5110.913916       NaN       NaN       NaN       NaN       NaN
# 131027  2389.969100       NaN       NaN       NaN       NaN       NaN
# 131028  3869.211034       NaN       NaN       NaN       NaN       NaN
# 131029  2755.398561       NaN       NaN       NaN       NaN       NaN
# 131030  2116.566505       NaN       NaN       NaN       NaN       NaN
# ...             ...       ...       ...       ...       ...       ...
# 141021   211.447645  0.201529  0.255884  0.202371  0.166218  0.173998
# 141022   194.839454  0.186121  0.231312  0.211827  0.196422  0.174319
# 141023   344.786940  0.237812  0.162050  0.153346  0.197669  0.249123
# 141024   275.930495  0.233152  0.200926  0.174560  0.174439  0.216924
# 141025   304.607179  0.233197  0.167416  0.162873  0.196231  0.240283
#
# [10000 rows x 11 columns]

# %%
def plot_feature_importance(importance,names,model_type):
    import matplotlib.pyplot as plt
    #Create arrays from feature importance and feature names
    feature_importance = np.array(importance)
    feature_names = np.array(names)
    
    #Create a DataFrame using a Dictionary
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)
    
    #Sort the DataFrame in order decreasing feature importance
    fi_df.sort_values(by=['feature_importance'], ascending=False, inplace=True)
    
    #Define size of bar plot
    plt.figure(figsize=(10,35))
    #Plot Searborn bar chart
    plt.barh(width=fi_df['feature_importance'], y=fi_df['feature_names'])
    #Add chart labels
    plt.title(model_type + ' FEATURE IMPORTANCE')
    plt.xlabel('FEATURE IMPORTANCE')
    plt.ylabel('FEATURE NAMES')
    
plot_feature_importance(container.module.model.get_feature_importance(), container.config.columns_x, 'TOP 100')

# %%
# TODO: Implement "container.get_sample_predictions()" that returns df in trainval data
df_val_preds["next"] = (df_val_preds["close"].shift(container.config.num_future_candles) / df_val_preds["close"]) - 1
df_val_preds["argmax_ml"] = df_val_preds[[f"ml_{x}"for x in range(5)]].idxmax(axis=1)
df_val_preds.loc[df_val_preds["argmax_ml"] == "ml_4"]
# Out:
#                             date      open      high       low     close  \
# 131425 2021-05-17 04:15:00+00:00  43147.31  43800.00  42700.93  43553.95
# 131426 2021-05-17 04:30:00+00:00  43553.83  44300.00  43120.12  43138.95
# 131428 2021-05-17 05:00:00+00:00  43582.60  43800.00  43229.12  43295.15
# 131429 2021-05-17 05:15:00+00:00  43295.15  43369.81  42856.92  42940.97
# 131430 2021-05-17 05:30:00+00:00  42940.97  43324.19  42500.00  42646.57
# ...                          ...       ...       ...       ...       ...
# 141013 2021-08-25 01:15:00+00:00  47813.26  47908.69  47739.45  47823.60
# 141014 2021-08-25 01:30:00+00:00  47823.59  48035.98  47793.27  48029.74
# 141017 2021-08-25 02:15:00+00:00  48208.51  48208.51  48033.27  48100.01
# 141023 2021-08-25 03:45:00+00:00  48191.08  48248.23  47965.00  47975.93
# 141025 2021-08-25 04:15:00+00:00  48155.56  48230.00  47964.34  47978.77
#
#              volume      ml_0      ml_1      ml_2      ml_3      ml_4  \
# 131425  3136.411829  0.358041  0.073891  0.054471  0.072139  0.441457
# 131426  2543.326712  0.320938  0.059769  0.040835  0.058119  0.520339
# 131428  1762.700218  0.369821  0.067685  0.042813  0.060086  0.459594
# 131429  2151.894111  0.341592  0.058220  0.037627  0.054436  0.508125
# 131430  2191.744143  0.351220  0.054917  0.037836  0.054672  0.501355
# ...             ...       ...       ...       ...       ...       ...
# 141013   367.466489  0.246611  0.163032  0.142366  0.180546  0.267446
# 141014   274.782834  0.229451  0.210536  0.169417  0.158780  0.231816
# 141017   276.441309  0.221751  0.205182  0.170183  0.181094  0.221790
# 141023   344.786940  0.237812  0.162050  0.153346  0.197669  0.249123
# 141025   304.607179  0.233197  0.167416  0.162873  0.196231  0.240283
#
#             next argmax_ml
# 131425 -0.014660      ml_4
# 131426  0.000194      ml_4
# 131428 -0.003608      ml_4
# 131429  0.014941      ml_4
# 131430  0.015208      ml_4
# ...          ...       ...
# 141013  0.003853      ml_4
# 141014 -0.004507      ml_4
# 141017  0.001168      ml_4
# 141023  0.005726      ml_4
# 141025 -0.000059      ml_4
#
# [4736 rows x 13 columns]

# %% [markdown]
# # Backtesting: Model Validation

# %%
MODEL_NAME = "15n60-catboost_l1"
MODEL_VER = "v0"  # Max ver: v0
fullname = MODEL_NAME + ":" + MODEL_VER

# %%
"""
This strategy will backtested in Train and Validation date.
To make sure the model was fitted correctly, you need to know that you model is predicting accurately in this date.
Create the strategy that BUYS when the ML Model predicts the future is going to UP, and do the same for the sell.
The strategy doesn't need to be trend following, but the final backtest results must profitable steadily.
"""

def val_strategy():
    """ Start Strategy Code """
    from freqtrade.nbtools.strategy import INbStrategy
    from freqtrade.nbtools.remote_utils import load_lightning_container
    from freqtrade.ml.container import LightningContainer
    from pandas import DataFrame
    from functools import reduce
    import numpy as np  # noqa
    import pandas as pd  # noqa
    import talib.abstract as ta
    
    LIGHTNING_CONTAINER_NAME = "[|LIGHTNING_CONTAINER_NAME|]"
    lightning_container = load_lightning_container(LIGHTNING_CONTAINER_NAME, LIGHTNING_CONTAINER_NAME, version="[|VERSION|]")        
    tp = str(int(lightning_container.config.timeframe.replace("m", "")) * lightning_container.config.num_future_candles)

    class NotebookStrategy(INbStrategy):
        # These attributes are REQUIRED!
        timeframe = lightning_container.config.timeframe
        minimal_roi = {tp: -1}
        stoploss = -999
        startup_candle_count: int = 500
                    
        def populate_indicators(self, dataframe: DataFrame, metadata: dict) -> DataFrame:
            dataframe = lightning_container.predict(dataframe)
            num_classes = lightning_container.config.num_classification_classes
            dataframe["argmax_ml"] = dataframe[[f"ml_{x}"for x in range(num_classes)]].idxmax(axis=1)
            return dataframe

        def populate_buy_trend(self, dataframe: DataFrame, metadata: dict) -> DataFrame:
            conditions = [
                dataframe["argmax_ml"] == "ml_4",
                dataframe['volume'] > 0,
            ]
            
            dataframe.loc[reduce(lambda x, y: x & y, conditions), 'buy'] = 1
                        
            return dataframe

        def populate_sell_trend(self, dataframe: DataFrame, metadata: dict) -> DataFrame:
            num_candles_forward = lightning_container.config.num_future_candles
            conditions = [
                dataframe['buy'].shift(num_candles_forward) == 1,
                dataframe['volume'] > 0,
            ]
            
            dataframe.loc[reduce(lambda x, y: x & y, conditions), 'sell'] = 1

            return dataframe
    """ End Strategy Code """

stats, summary, preset = start_backtesting(val_strategy, MODEL_NAME, "val", version=MODEL_VER)
trades = pd.DataFrame(stats["strategy"]["NotebookStrategy"]["trades"])
plotting.plot_profits_timerange(trades, timerange=preset.timerange, path_mount=PATH_MOUNT, name=fullname)
# Out:
# INFO:freqtrade.nbtools.preset.base_preset:Overwriting pairs (from 0 to 61 pairs)
# INFO:freqtrade.nbtools.preset.base_preset:Overwriting pairs (from 0 to 61 pairs)
# INFO:freqtrade.nbtools.preset.base_preset:Setting config for ml_val_15n60-catboost_l1 ...
# INFO:freqtrade.nbtools.preset.base_preset:Setting arg `datadir` to c:\CS\Python\crypto-collection\freqtrade\mount\data\binance
# INFO:freqtrade.nbtools.preset.base_preset:Setting arg `timerange` to 20160101-20210602
# INFO:freqtrade.loggers:Verbosity set to 0
# INFO:freqtrade.configuration.configuration:Using max_open_trades: 6 ...
# INFO:freqtrade.configuration.configuration:Parameter --timerange detected: 20160101-20210602 ...
# INFO:freqtrade.configuration.configuration:Using user-data directory: c:\CS\Python\crypto-collection\freqtrade\superft\user_data ...
# INFO:freqtrade.configuration.configuration:Using data directory: c:\CS\Python\crypto-collection\freqtrade\mount\data\binance ...
# INFO:freqtrade.configuration.check_exchange:Checking exchange...
# INFO:freqtrade.configuration.check_exchange:Exchange "binance" is officially supported by the Freqtrade development team.
# INFO:freqtrade.configuration.config_validation:Validating configuration ...
# INFO:freqtrade.strategy.hyper:No params for buy found, using default values.
# INFO:freqtrade.strategy.hyper:No params for sell found, using default values.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'order_types' with value in config file: {'buy': 'limit', 'sell': 'limit', 'forcesell': 'market', 'emergencysell': 'market', 'stoploss': 'market', 'stoploss_on_exchange': False, 'stoploss_on_exchange_interval': 60}.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'stake_currency' with value in config file: USDT.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'stake_amount' with value in config file: 15.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'unfilledtimeout' with value in config file: {'buy': 300, 'sell': 60, 'unit': 'seconds'}.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'use_sell_signal' with value in config file: True.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'sell_profit_only' with value in config file: False.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'ignore_roi_if_buy_signal' with value in config file: True.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'sell_profit_offset' with value in config file: 0.0.
# INFO:freqtrade.nbtools.helper:Strategy using minimal_roi: {'60': -1}
# INFO:freqtrade.nbtools.helper:Strategy using timeframe: 15m
# INFO:freqtrade.nbtools.helper:Strategy using stoploss: -999
# INFO:freqtrade.nbtools.helper:Strategy using trailing_stop: False
# INFO:freqtrade.nbtools.helper:Strategy using trailing_stop_positive_offset: 0.0
# INFO:freqtrade.nbtools.helper:Strategy using trailing_only_offset_is_reached: False
# INFO:freqtrade.nbtools.helper:Strategy using use_custom_stoploss: False
# INFO:freqtrade.nbtools.helper:Strategy using process_only_new_candles: False
# INFO:freqtrade.nbtools.helper:Strategy using order_types: {'buy': 'limit', 'sell': 'limit', 'forcesell': 'market', 'emergencysell': 'market', 'stoploss': 'market', 'stoploss_on_exchange': False, 'stoploss_on_exchange_interval': 60}
# INFO:freqtrade.nbtools.helper:Strategy using order_time_in_force: {'buy': 'gtc', 'sell': 'gtc'}
# INFO:freqtrade.nbtools.helper:Strategy using stake_currency: USDT
# INFO:freqtrade.nbtools.helper:Strategy using stake_amount: 15
# INFO:freqtrade.nbtools.helper:Strategy using protections: []
# INFO:freqtrade.nbtools.helper:Strategy using startup_candle_count: 500
# INFO:freqtrade.nbtools.helper:Strategy using unfilledtimeout: {'buy': 300, 'sell': 60, 'unit': 'seconds'}
# INFO:freqtrade.nbtools.helper:Strategy using use_sell_signal: True
# INFO:freqtrade.nbtools.helper:Strategy using sell_profit_only: False
# INFO:freqtrade.nbtools.helper:Strategy using ignore_roi_if_buy_signal: True
# INFO:freqtrade.nbtools.helper:Strategy using sell_profit_offset: 0.0
# INFO:freqtrade.nbtools.helper:Strategy using disable_dataframe_checks: False
# INFO:freqtrade.nbtools.helper:Strategy using ignore_buying_expired_candle_after: 0
# INFO:freqtrade.exchange.exchange:Instance is running with dry_run enabled
# INFO:freqtrade.exchange.exchange:Using CCXT 1.52.83
# INFO:freqtrade.exchange.exchange:Applying additional ccxt config: {'enableRateLimit': True}
# INFO:freqtrade.exchange.exchange:Applying additional ccxt config: {'enableRateLimit': True, 'rateLimit': 200}
# INFO:freqtrade.exchange.exchange:Using Exchange "Binance"
# INFO:freqtrade.resolvers.exchange_resolver:Using resolved exchange 'Binance'...
# INFO:freqtrade.configuration.config_validation:Validating configuration ...
# INFO:freqtrade.resolvers.iresolver:Using resolved pairlist StaticPairList from 'C:\CS\Python\crypto-collection\freqtrade\superft\freqtrade\plugins\pairlist\StaticPairList.py'...
# INFO:freqtrade.nbtools.backtest:Backtesting...
# INFO:freqtrade.nbtools.backtest:DATALOADER: Dataset with hash `-5768756422924023626` doesn't exist. Loading from disk...
# INFO:freqtrade.data.history.history_utils:Using indicator startup period: 1000 ...
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair AAVE/USDT, data starts at 2020-10-15 03:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair ADA/USDT, data starts at 2018-04-17 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair ALGO/USDT, data starts at 2019-06-22 00:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair ANKR/USDT, data starts at 2019-07-23 14:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair ATOM/USDT, data starts at 2019-04-29 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair AVAX/USDT, data starts at 2020-09-22 06:30:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair BAT/USDT, data starts at 2019-03-04 10:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair BCH/USDT, data starts at 2019-11-28 10:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair BNT/USDT, data starts at 2020-02-06 10:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair BTC/USDT, data starts at 2017-08-17 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair BTT/USDT, data starts at 2019-01-31 10:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair CHZ/USDT, data starts at 2019-09-06 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair COMP/USDT, data starts at 2020-06-25 06:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair CRV/USDT, data starts at 2020-08-15 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair DASH/USDT, data starts at 2019-03-28 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair DCR/USDT, data starts at 2020-07-30 05:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair DOGE/USDT, data starts at 2019-07-05 12:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair DOT/USDT, data starts at 2020-08-18 23:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair EGLD/USDT, data starts at 2020-09-03 03:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair ENJ/USDT, data starts at 2019-04-18 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair EOS/USDT, data starts at 2018-05-28 05:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair ETC/USDT, data starts at 2018-06-12 02:30:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair ETH/USDT, data starts at 2017-08-17 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair FIL/USDT, data starts at 2020-10-15 17:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair FTM/USDT, data starts at 2019-06-11 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair FTT/USDT, data starts at 2019-12-20 03:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair HNT/USDT, data starts at 2020-09-24 09:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair HOT/USDT, data starts at 2019-02-18 10:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair ICX/USDT, data starts at 2018-06-13 08:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair KSM/USDT, data starts at 2020-09-04 11:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair LINK/USDT, data starts at 2019-01-16 10:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair LTC/USDT, data starts at 2017-12-13 03:30:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair LUNA/USDT, data starts at 2020-08-21 10:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair MANA/USDT, data starts at 2020-08-06 10:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair MATIC/USDT, data starts at 2019-04-26 15:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair MKR/USDT, data starts at 2020-07-23 14:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair NANO/USDT, data starts at 2019-04-03 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair NEAR/USDT, data starts at 2020-10-14 05:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair NEO/USDT, data starts at 2017-11-20 03:30:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair OMG/USDT, data starts at 2019-04-03 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair ONE/USDT, data starts at 2019-06-01 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair ONT/USDT, data starts at 2018-06-08 07:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair QTUM/USDT, data starts at 2018-03-19 08:45:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair RVN/USDT, data starts at 2019-09-25 12:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair SNX/USDT, data starts at 2020-07-09 12:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair SOL/USDT, data starts at 2020-08-11 06:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair SUSHI/USDT, data starts at 2020-09-01 11:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair TFUEL/USDT, data starts at 2019-05-24 10:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair THETA/USDT, data starts at 2019-04-10 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair TRX/USDT, data starts at 2018-06-11 11:30:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair UNI/USDT, data starts at 2020-09-17 03:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair VET/USDT, data starts at 2018-07-25 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair WAVES/USDT, data starts at 2019-01-18 10:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair XEM/USDT, data starts at 2020-11-24 13:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair XLM/USDT, data starts at 2018-05-31 09:30:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair XMR/USDT, data starts at 2019-03-15 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair XRP/USDT, data starts at 2018-05-04 08:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair YFI/USDT, data starts at 2020-08-10 12:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair ZEC/USDT, data starts at 2019-03-21 04:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair ZIL/USDT, data starts at 2019-02-19 11:00:00
# WARNING:freqtrade.data.history.idatahandler:Missing data at start for pair ZRX/USDT, data starts at 2019-02-28 04:00:00
# INFO:freqtrade.nbtools.helper:"Load BT Data" executed in 13.54s
# INFO:freqtrade.nbtools.backtest:Loading data from 2017-08-17 04:00:00 up to 2021-06-02 00:00:00 (1384 days).
# WARNING:freqtrade.configuration.timerange:Moving start-date by 500 candles to account for startup time.
# INFO:freqtrade.nbtools.backtest:Dataload complete. Calculating indicators
# INFO:freqtrade.optimize.backtesting:Running backtesting for Strategy NotebookStrategy
# Populating Indicators:   0%|          | 0/61 [00:00<?, ?it/s]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevlow_{i}"] = (df_onepair["low"].shift(i) - df_onepair["low"]) / df_onepair["low"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevopen_{i}"] = (df_onepair["open"].shift(i) - df_onepair["open"]) / df_onepair["open"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevvol_{i}"] = (df_onepair["volume"].shift(i) - df_onepair["volume"]) / df_onepair["volume"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:90: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevhigh_{i}"] = (df_onepair["high"].shift(i) - df_onepair["high"]) / df_onepair["high"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:100: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair["ml_volume_pctchange"] = df_onepair['volume'].pct_change()
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:101: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair['ml_z_score_120'] = (
# INFO:freqtrade.optimize.backtesting:Backtesting with data from 2017-08-22 09:00:00 up to 2021-06-02 00:00:00 (1379 days).
# INFO:freqtrade.nbtools.helper:"Backtest" executed in 131.73s
# INFO:freqtrade.nbtools.backtest:Logging preset...
# INFO:freqtrade.nbtools.backtest:[LOG PRESET OFFLINE SUCCESS]
# INFO:freqtrade.nbtools.backtest:Sync preset with name: ml_val_15n60-catboost_l1__backtest-2021-09-06_09-52-50
# INFO:freqtrade.nbtools.backtest:with random name: broken-ironman-electricity
# INFO:freqtrade.nbtools.backtest:[WANDB LOG PRESET CONTINUES IN BACKGROUND]
# INFO:freqtrade.nbtools.helper:"Whole Backtesting Process (Backtest + Log)" executed in 143.43s
# Preset Name: ml_val_15n60-catboost_l1__backtest-2021-09-06_09-52-50
#                           Portfolio Summary
# Trades                                61210
# Avg. Stake Amount                      15.0
# Number of Pairs                          61
# Min Balance                           -0.42
# Max Balance                         2680.79
# Final Balance                       2679.65
# -                                         -
# Wins                                  34027
# Loses                                 27183
# Win Rate                             55.59%
#  -                                       -
# Profit Factor                          1.57
# Expectancy (% Per Trade)               0.29
#   -                                     -
# Avg. Profit (%)                        0.29
# Avg. Profit (%) Winners                1.44
# Avg. Profit (%) Losers                -1.14
# Net Profit (Rate)                    178.46
# Sum Profit Winners (Rate)            489.14
# Sum Profit Losers (Rate)            -310.68
# Avg. Duration               0 days 01:20:17
# Avg. Duration Winners       0 days 01:15:58
# Avg. Duration Losers        0 days 01:25:40

# %% [markdown]
# # Backtesting: Strategy Optimization

# %%
"""
Phase where you can trial and error, plug and play model with any strategy, until get the best results.
In this phase, feel free to combine the trained model with a variety of technical indicators or ensemble with another model.

TIP: High threshold no trendline |OR| Low threshold with trendline
"""

def opt_strategy():
    """ Start Strategy Code """
    from freqtrade.nbtools.strategy import INbStrategy
    from freqtrade.nbtools.remote_utils import load_lightning_container
    from freqtrade.ml.container import LightningContainer
    from pandas import DataFrame
    from functools import reduce
    import freqtrade.vendor.qtpylib.indicators as qtpylib
    import numpy as np  # noqa
    import pandas as pd  # noqa
    import talib.abstract as ta
    import pandas_ta as pta
    
    LIGHTNING_CONTAINER_NAME = "[|LIGHTNING_CONTAINER_NAME|]"
    lightning_container = load_lightning_container(LIGHTNING_CONTAINER_NAME, LIGHTNING_CONTAINER_NAME, version="[|VERSION|]")        
    tp = str(int(lightning_container.config.timeframe.replace("m", "")) * lightning_container.config.num_future_candles)
    
    class NotebookStrategy(INbStrategy):
        # These attributes are REQUIRED!
        timeframe = lightning_container.config.timeframe
        minimal_roi = {tp: -1}
        stoploss = -0.99
        startup_candle_count: int = 500
        
        def populate_indicators(self, dataframe: DataFrame, metadata: dict) -> DataFrame:
            dataframe["ema_trend"] = ta.EMA(dataframe, timeperiod=200)
            dataframe["ema_volume"] = ta.EMA(dataframe["volume"], timeperiod=50)
            
            dataframe = lightning_container.predict(dataframe)
            num_classes = lightning_container.config.num_classification_classes
            dataframe["argmax_ml"] = dataframe[[f"ml_{x}"for x in range(num_classes)]].idxmax(axis=1)
            
            return dataframe

        def populate_buy_trend(self, dataframe: DataFrame, metadata: dict) -> DataFrame:
            conditions = [
                # Model Filter
                dataframe['argmax_ml'] == "ml_4",
                dataframe['ml_4'] > 0.6,
                
                # NOTE: Start TA filter #
                # dataframe["close"] > dataframe["ema_trend"],
                dataframe['volume'] > 0,
            ]
            
            dataframe.loc[reduce(lambda x, y: x & y, conditions), 'buy'] = 1
            return dataframe

        def populate_sell_trend(self, dataframe: DataFrame, metadata: dict) -> DataFrame:
            num_candles_forward = lightning_container.config.num_future_candles
            conditions = [
                dataframe['buy'].shift(num_candles_forward) == 1,
                dataframe['buy'] == 0,
                dataframe['volume'] > 0,
            ]
            
            dataframe.loc[reduce(lambda x, y: x & y, conditions), 'sell'] = 1
            return dataframe
    """ End Strategy Code """


stats, summary, preset = start_backtesting(opt_strategy, MODEL_NAME, "opt", version=MODEL_VER)
trades = pd.DataFrame(stats["strategy"]["NotebookStrategy"]["trades"])
plotting.plot_profits_timerange(trades, timerange=preset.timerange, path_mount=PATH_MOUNT, name=fullname)
# Out:
# INFO:freqtrade.nbtools.preset.base_preset:Overwriting pairs (from 0 to 61 pairs)
# INFO:freqtrade.nbtools.preset.base_preset:Overwriting pairs (from 0 to 61 pairs)
# INFO:freqtrade.nbtools.preset.base_preset:Setting config for ml_opt_15n60-catboost_l1 ...
# INFO:freqtrade.nbtools.preset.base_preset:Setting arg `datadir` to c:\CS\Python\crypto-collection\freqtrade\mount\data\binance
# INFO:freqtrade.nbtools.preset.base_preset:Setting arg `timerange` to 20210603-20210717
# INFO:freqtrade.loggers:Verbosity set to 0
# INFO:freqtrade.configuration.configuration:Using max_open_trades: 6 ...
# INFO:freqtrade.configuration.configuration:Parameter --timerange detected: 20210603-20210717 ...
# INFO:freqtrade.configuration.configuration:Using user-data directory: c:\CS\Python\crypto-collection\freqtrade\superft\user_data ...
# INFO:freqtrade.configuration.configuration:Using data directory: c:\CS\Python\crypto-collection\freqtrade\mount\data\binance ...
# INFO:freqtrade.configuration.check_exchange:Checking exchange...
# INFO:freqtrade.configuration.check_exchange:Exchange "binance" is officially supported by the Freqtrade development team.
# INFO:freqtrade.configuration.config_validation:Validating configuration ...
# INFO:freqtrade.strategy.hyper:No params for buy found, using default values.
# INFO:freqtrade.strategy.hyper:No params for sell found, using default values.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'order_types' with value in config file: {'buy': 'limit', 'sell': 'limit', 'forcesell': 'market', 'emergencysell': 'market', 'stoploss': 'market', 'stoploss_on_exchange': False, 'stoploss_on_exchange_interval': 60}.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'stake_currency' with value in config file: USDT.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'stake_amount' with value in config file: 15.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'unfilledtimeout' with value in config file: {'buy': 300, 'sell': 60, 'unit': 'seconds'}.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'use_sell_signal' with value in config file: True.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'sell_profit_only' with value in config file: False.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'ignore_roi_if_buy_signal' with value in config file: True.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'sell_profit_offset' with value in config file: 0.0.
# INFO:freqtrade.nbtools.helper:Strategy using minimal_roi: {'60': -1}
# INFO:freqtrade.nbtools.helper:Strategy using timeframe: 15m
# INFO:freqtrade.nbtools.helper:Strategy using stoploss: -0.99
# INFO:freqtrade.nbtools.helper:Strategy using trailing_stop: False
# INFO:freqtrade.nbtools.helper:Strategy using trailing_stop_positive_offset: 0.0
# INFO:freqtrade.nbtools.helper:Strategy using trailing_only_offset_is_reached: False
# INFO:freqtrade.nbtools.helper:Strategy using use_custom_stoploss: False
# INFO:freqtrade.nbtools.helper:Strategy using process_only_new_candles: False
# INFO:freqtrade.nbtools.helper:Strategy using order_types: {'buy': 'limit', 'sell': 'limit', 'forcesell': 'market', 'emergencysell': 'market', 'stoploss': 'market', 'stoploss_on_exchange': False, 'stoploss_on_exchange_interval': 60}
# INFO:freqtrade.nbtools.helper:Strategy using order_time_in_force: {'buy': 'gtc', 'sell': 'gtc'}
# INFO:freqtrade.nbtools.helper:Strategy using stake_currency: USDT
# INFO:freqtrade.nbtools.helper:Strategy using stake_amount: 15
# INFO:freqtrade.nbtools.helper:Strategy using protections: []
# INFO:freqtrade.nbtools.helper:Strategy using startup_candle_count: 500
# INFO:freqtrade.nbtools.helper:Strategy using unfilledtimeout: {'buy': 300, 'sell': 60, 'unit': 'seconds'}
# INFO:freqtrade.nbtools.helper:Strategy using use_sell_signal: True
# INFO:freqtrade.nbtools.helper:Strategy using sell_profit_only: False
# INFO:freqtrade.nbtools.helper:Strategy using ignore_roi_if_buy_signal: True
# INFO:freqtrade.nbtools.helper:Strategy using sell_profit_offset: 0.0
# INFO:freqtrade.nbtools.helper:Strategy using disable_dataframe_checks: False
# INFO:freqtrade.nbtools.helper:Strategy using ignore_buying_expired_candle_after: 0
# INFO:freqtrade.exchange.exchange:Instance is running with dry_run enabled
# INFO:freqtrade.exchange.exchange:Using CCXT 1.52.83
# INFO:freqtrade.exchange.exchange:Applying additional ccxt config: {'enableRateLimit': True}
# INFO:freqtrade.exchange.exchange:Applying additional ccxt config: {'enableRateLimit': True, 'rateLimit': 200}
# INFO:freqtrade.exchange.exchange:Using Exchange "Binance"
# INFO:freqtrade.resolvers.exchange_resolver:Using resolved exchange 'Binance'...
# INFO:freqtrade.configuration.config_validation:Validating configuration ...
# INFO:freqtrade.resolvers.iresolver:Using resolved pairlist StaticPairList from 'C:\CS\Python\crypto-collection\freqtrade\superft\freqtrade\plugins\pairlist\StaticPairList.py'...
# INFO:freqtrade.nbtools.backtest:Backtesting...
# INFO:freqtrade.nbtools.backtest:DATALOADER: Dataset with hash `2298657189825777106` exists in cache!
# INFO:freqtrade.nbtools.helper:"Load BT Data" executed in 0.08s
# INFO:freqtrade.nbtools.backtest:Loading data from 2021-05-23 14:00:00 up to 2021-07-17 00:00:00 (54 days).
# INFO:freqtrade.nbtools.backtest:Dataload complete. Calculating indicators
# INFO:freqtrade.optimize.backtesting:Running backtesting for Strategy NotebookStrategy
# Populating Indicators:   0%|          | 0/61 [00:00<?, ?it/s]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevlow_{i}"] = (df_onepair["low"].shift(i) - df_onepair["low"]) / df_onepair["low"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevopen_{i}"] = (df_onepair["open"].shift(i) - df_onepair["open"]) / df_onepair["open"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevvol_{i}"] = (df_onepair["volume"].shift(i) - df_onepair["volume"]) / df_onepair["volume"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:90: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevhigh_{i}"] = (df_onepair["high"].shift(i) - df_onepair["high"]) / df_onepair["high"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:100: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair["ml_volume_pctchange"] = df_onepair['volume'].pct_change()
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:101: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair['ml_z_score_120'] = (
# INFO:freqtrade.nbtools.backtest:===============================
# INFO:freqtrade.nbtools.backtest:|  'ml_test_15n60-catboost_l1__backtest-2021-09-06_09-56-37'
# INFO:freqtrade.nbtools.backtest:|  WANDB LOG PRESET FINISHED
# INFO:freqtrade.nbtools.backtest:===============================
# INFO:freqtrade.optimize.backtesting:Backtesting with data from 2021-05-28 19:00:00 up to 2021-07-17 00:00:00 (49 days).
# INFO:freqtrade.nbtools.helper:"Backtest" executed in 15.67s
# INFO:freqtrade.nbtools.backtest:Logging preset...
# INFO:freqtrade.nbtools.backtest:[LOG PRESET OFFLINE SUCCESS]
# INFO:freqtrade.nbtools.backtest:Sync preset with name: ml_opt_15n60-catboost_l1__backtest-2021-09-06_09-57-07
# INFO:freqtrade.nbtools.backtest:with random name: furious-doraemon-necklace
# INFO:freqtrade.nbtools.backtest:[WANDB LOG PRESET CONTINUES IN BACKGROUND]
# INFO:freqtrade.nbtools.helper:"Whole Backtesting Process (Backtest + Log)" executed in 16.91s
# Preset Name: ml_opt_15n60-catboost_l1__backtest-2021-09-06_09-57-07
#                           Portfolio Summary
# Trades                                  273
# Avg. Stake Amount                      15.0
# Number of Pairs                          50
# Min Balance                           -8.03
# Max Balance                             9.1
# Final Balance                          8.48
# -                                         -
# Wins                                    137
# Loses                                   136
# Win Rate                             50.18%
#  -                                       -
# Profit Factor                          1.23
# Expectancy (% Per Trade)               0.21
#   -                                     -
# Avg. Profit (%)                        0.21
# Avg. Profit (%) Winners                 2.2
# Avg. Profit (%) Losers                 -1.8
# Net Profit (Rate)                      0.56
# Sum Profit Winners (Rate)              3.01
# Sum Profit Losers (Rate)              -2.44
# Avg. Duration               0 days 01:03:40
# Avg. Duration Winners       0 days 00:57:55
# Avg. Duration Losers        0 days 01:09:29

# %% [markdown]
# # Backtesting: Final Phase

# %%
"""
This is a phase where you believe your strategy is now optimized along with your model.
This is not trial and error phase, and you can only run this phase ONCE every "good" optimized strategy to avoid biased results.
"""
stats, summary, preset = start_backtesting(opt_strategy, MODEL_NAME, "test", version=MODEL_VER)
trades = pd.DataFrame(stats["strategy"]["NotebookStrategy"]["trades"])
plotting.plot_profits_timerange(trades, timerange=preset.timerange, path_mount=PATH_MOUNT, name=fullname)
# Out:
# INFO:freqtrade.nbtools.preset.base_preset:Overwriting pairs (from 0 to 61 pairs)
# INFO:freqtrade.nbtools.preset.base_preset:Overwriting pairs (from 0 to 61 pairs)
# INFO:freqtrade.nbtools.preset.base_preset:Setting config for ml_test_15n60-catboost_l1 ...
# INFO:freqtrade.nbtools.preset.base_preset:Setting arg `datadir` to c:\CS\Python\crypto-collection\freqtrade\mount\data\binance
# INFO:freqtrade.nbtools.preset.base_preset:Setting arg `timerange` to 20210718-20210901
# INFO:freqtrade.loggers:Verbosity set to 0
# INFO:freqtrade.configuration.configuration:Using max_open_trades: 6 ...
# INFO:freqtrade.configuration.configuration:Parameter --timerange detected: 20210718-20210901 ...
# INFO:freqtrade.configuration.configuration:Using user-data directory: c:\CS\Python\crypto-collection\freqtrade\superft\user_data ...
# INFO:freqtrade.configuration.configuration:Using data directory: c:\CS\Python\crypto-collection\freqtrade\mount\data\binance ...
# INFO:freqtrade.configuration.check_exchange:Checking exchange...
# INFO:freqtrade.configuration.check_exchange:Exchange "binance" is officially supported by the Freqtrade development team.
# INFO:freqtrade.configuration.config_validation:Validating configuration ...
# INFO:freqtrade.strategy.hyper:No params for buy found, using default values.
# INFO:freqtrade.strategy.hyper:No params for sell found, using default values.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'order_types' with value in config file: {'buy': 'limit', 'sell': 'limit', 'forcesell': 'market', 'emergencysell': 'market', 'stoploss': 'market', 'stoploss_on_exchange': False, 'stoploss_on_exchange_interval': 60}.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'stake_currency' with value in config file: USDT.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'stake_amount' with value in config file: 15.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'unfilledtimeout' with value in config file: {'buy': 300, 'sell': 60, 'unit': 'seconds'}.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'use_sell_signal' with value in config file: True.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'sell_profit_only' with value in config file: False.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'ignore_roi_if_buy_signal' with value in config file: True.
# INFO:freqtrade.resolvers.strategy_resolver:Override strategy 'sell_profit_offset' with value in config file: 0.0.
# INFO:freqtrade.nbtools.helper:Strategy using minimal_roi: {'60': -1}
# INFO:freqtrade.nbtools.helper:Strategy using timeframe: 15m
# INFO:freqtrade.nbtools.helper:Strategy using stoploss: -0.99
# INFO:freqtrade.nbtools.helper:Strategy using trailing_stop: False
# INFO:freqtrade.nbtools.helper:Strategy using trailing_stop_positive_offset: 0.0
# INFO:freqtrade.nbtools.helper:Strategy using trailing_only_offset_is_reached: False
# INFO:freqtrade.nbtools.helper:Strategy using use_custom_stoploss: False
# INFO:freqtrade.nbtools.helper:Strategy using process_only_new_candles: False
# INFO:freqtrade.nbtools.helper:Strategy using order_types: {'buy': 'limit', 'sell': 'limit', 'forcesell': 'market', 'emergencysell': 'market', 'stoploss': 'market', 'stoploss_on_exchange': False, 'stoploss_on_exchange_interval': 60}
# INFO:freqtrade.nbtools.helper:Strategy using order_time_in_force: {'buy': 'gtc', 'sell': 'gtc'}
# INFO:freqtrade.nbtools.helper:Strategy using stake_currency: USDT
# INFO:freqtrade.nbtools.helper:Strategy using stake_amount: 15
# INFO:freqtrade.nbtools.helper:Strategy using protections: []
# INFO:freqtrade.nbtools.helper:Strategy using startup_candle_count: 500
# INFO:freqtrade.nbtools.helper:Strategy using unfilledtimeout: {'buy': 300, 'sell': 60, 'unit': 'seconds'}
# INFO:freqtrade.nbtools.helper:Strategy using use_sell_signal: True
# INFO:freqtrade.nbtools.helper:Strategy using sell_profit_only: False
# INFO:freqtrade.nbtools.helper:Strategy using ignore_roi_if_buy_signal: True
# INFO:freqtrade.nbtools.helper:Strategy using sell_profit_offset: 0.0
# INFO:freqtrade.nbtools.helper:Strategy using disable_dataframe_checks: False
# INFO:freqtrade.nbtools.helper:Strategy using ignore_buying_expired_candle_after: 0
# INFO:freqtrade.exchange.exchange:Instance is running with dry_run enabled
# INFO:freqtrade.exchange.exchange:Using CCXT 1.52.83
# INFO:freqtrade.exchange.exchange:Applying additional ccxt config: {'enableRateLimit': True}
# INFO:freqtrade.exchange.exchange:Applying additional ccxt config: {'enableRateLimit': True, 'rateLimit': 200}
# INFO:freqtrade.exchange.exchange:Using Exchange "Binance"
# INFO:freqtrade.resolvers.exchange_resolver:Using resolved exchange 'Binance'...
# INFO:freqtrade.configuration.config_validation:Validating configuration ...
# INFO:freqtrade.resolvers.iresolver:Using resolved pairlist StaticPairList from 'C:\CS\Python\crypto-collection\freqtrade\superft\freqtrade\plugins\pairlist\StaticPairList.py'...
# INFO:freqtrade.nbtools.backtest:Backtesting...
# INFO:freqtrade.nbtools.backtest:DATALOADER: Dataset with hash `1791919418681145299` exists in cache!
# INFO:freqtrade.nbtools.helper:"Load BT Data" executed in 0.08s
# INFO:freqtrade.nbtools.backtest:Loading data from 2021-07-07 14:00:00 up to 2021-09-01 00:00:00 (55 days).
# INFO:freqtrade.nbtools.backtest:Dataload complete. Calculating indicators
# INFO:freqtrade.optimize.backtesting:Running backtesting for Strategy NotebookStrategy
# Populating Indicators:   0%|          | 0/61 [00:00<?, ?it/s]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:91: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevlow_{i}"] = (df_onepair["low"].shift(i) - df_onepair["low"]) / df_onepair["low"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:92: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevopen_{i}"] = (df_onepair["open"].shift(i) - df_onepair["open"]) / df_onepair["open"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevvol_{i}"] = (df_onepair["volume"].shift(i) - df_onepair["volume"]) / df_onepair["volume"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:90: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair[f"ml_prevhigh_{i}"] = (df_onepair["high"].shift(i) - df_onepair["high"]) / df_onepair["high"]
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:100: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair["ml_volume_pctchange"] = df_onepair['volume'].pct_change()
# C:\Users\User\AppData\Local\Temp/ipykernel_31596/2348130674.py:101: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_onepair['ml_z_score_120'] = (
# INFO:freqtrade.nbtools.backtest:===============================
# INFO:freqtrade.nbtools.backtest:|  'ml_opt_15n60-catboost_l1__backtest-2021-09-06_09-57-07'
# INFO:freqtrade.nbtools.backtest:|  WANDB LOG PRESET FINISHED
# INFO:freqtrade.nbtools.backtest:===============================
# INFO:freqtrade.optimize.backtesting:Backtesting with data from 2021-07-12 19:00:00 up to 2021-09-01 00:00:00 (50 days).
# INFO:freqtrade.nbtools.helper:"Backtest" executed in 15.63s
# INFO:freqtrade.nbtools.backtest:Logging preset...
# INFO:freqtrade.nbtools.backtest:[LOG PRESET OFFLINE SUCCESS]
# INFO:freqtrade.nbtools.backtest:Sync preset with name: ml_test_15n60-catboost_l1__backtest-2021-09-06_09-57-37
# INFO:freqtrade.nbtools.backtest:with random name: dumb-frieza-sword
# INFO:freqtrade.nbtools.backtest:[WANDB LOG PRESET CONTINUES IN BACKGROUND]
# INFO:freqtrade.nbtools.helper:"Whole Backtesting Process (Backtest + Log)" executed in 16.64s
# Preset Name: ml_test_15n60-catboost_l1__backtest-2021-09-06_09-57-37
#                           Portfolio Summary
# Trades                                   97
# Avg. Stake Amount                      15.0
# Number of Pairs                          35
# Min Balance                           -2.27
# Max Balance                           16.56
# Final Balance                         16.56
# -                                         -
# Wins                                     68
# Loses                                    29
# Win Rate                              70.1%
#  -                                       -
# Profit Factor                          4.24
# Expectancy (% Per Trade)               1.14
#   -                                     -
# Avg. Profit (%)                        1.14
# Avg. Profit (%) Winners                2.12
# Avg. Profit (%) Losers                -1.18
# Net Profit (Rate)                       1.1
# Sum Profit Winners (Rate)              1.44
# Sum Profit Losers (Rate)              -0.34
# Avg. Duration               0 days 01:00:27
# Avg. Duration Winners       0 days 00:59:20
# Avg. Duration Losers        0 days 01:03:06
# INFO:freqtrade.nbtools.backtest:===============================
# INFO:freqtrade.nbtools.backtest:|  'ml_test_15n60-catboost_l1__backtest-2021-09-06_09-57-37'
# INFO:freqtrade.nbtools.backtest:|  WANDB LOG PRESET FINISHED
# INFO:freqtrade.nbtools.backtest:===============================
